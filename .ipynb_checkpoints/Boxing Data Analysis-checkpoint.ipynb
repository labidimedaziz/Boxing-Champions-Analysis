# %% [markdown]
# # Questions to answer:
# ### 1- do horoscope signs  define good boxers (cuz d'amato said that: Aquarius, capricorn, taurus and  cancers make good boxers(source : teddy atlas in valuentertainement) ?
#
# ### 2- what are the physical characteristics found in most champion boxers ?
#
# ### 3-does race play a factor in boxing?
#
# ### 4-which style is the more prominent in champions(outside fighter, swarmer, puncher....)

# %% [markdown]
# ## Hypothesis:
# ### 1- no
# ### 2-height and reach give a significant advantage
# ### 3-no
# ### 4-different styles are better fitted for each divison

# %% [markdown]
# first let's collect some data:
# In our project we want to know the general characteristics that make a good boxer. The hardest part wich i though at first is gonna be easy is knowing who is considered a champion in boxing. "it's the guy with the belt normal human beings might say" and i said so too at the beginning but it's a little bit more complicated. i meant a lot more, There are way too many belts in boxing and it's really confusing. The WBA, WBC, WBO, and IBF are the four main belt organizations. These organizations rank boxers and award belts. There's also The Ring Magazine, which is a publication and not a belt organization, but they famously award belts to the best fighter they think is in that weight class. There's also the lineal champion, who is the guy who beat the guy who beat the guy who beat the guy all the way down to the first champion when there was only one belt.
# there's also women's boxing and the olympic's boxing aka amateur boxinch whick can't be overlooked since most of them turn pro
# and become world champions. we're gonna consider the IBO also its not that famous and it's not recognised by ring magazine but what the hell why not include it.
# So we're gonna consider them all the same

# %%
import requests
from bs4 import BeautifulSoup
#%load_ext cudf.pandas
import pandas as pd
links_lsit = ['https://en.wikipedia.org/wiki/List_of_WBA_world_champions', 'https://en.wikipedia.org/wiki/List_of_WBC_world_champions',
             'https://en.wikipedia.org/wiki/List_of_WBO_world_champions', 'https://en.wikipedia.org/wiki/List_of_The_Ring_world_champions',
             'https://en.wikipedia.org/wiki/List_of_IBF_world_champions', 'https://en.wikipedia.org/wiki/List_of_IBO_world_champions', 
            'https://en.wikipedia.org/wiki/List_of_IBF_female_world_champions', 'https://en.wikipedia.org/wiki/List_of_WBA_female_world_champions',
            'https://en.wikipedia.org/wiki/List_of_WBC_female_world_champions', 'https://en.wikipedia.org/wiki/List_of_WBO_female_world_champions',
             'https://en.wikipedia.org/wiki/List_of_WIBO_world_champions']

# %%
name_list = []

# %% [markdown]
# WBA

# %%
r = requests.get('https://en.wikipedia.org/wiki/List_of_WBA_world_champions')
soup = BeautifulSoup(r.text, 'html.parser')
for table in soup.find_all('table'):
    for row in table.find_all('tr'):
        td_tag = row.find('td', align='left')  # Find <td> tag with align="left"
        if td_tag: 
            try:
                anchor_tag = td_tag.find('a')  # Find <a> tag within <td> tag
                name_list.append(anchor_tag.text.strip())
            except:
                name_list.append(td_tag.text.strip())
            
# Create DataFrame outside the loops

# %% [markdown]
# should be 969 values

# %% [markdown]
# WBC

# %%
name_list_wbc = []
r = requests.get('https://en.wikipedia.org/wiki/List_of_WBC_world_champions')
soup = BeautifulSoup(r.text, 'html.parser')
for table in soup.find_all('table'):
    for row in table.find_all('tr'):
        td_tag = row.find('td', align='left')  # Find <td> tag with align="left"
        if td_tag: 
            try:
                anchor_tag = td_tag.find('a')  # Find <a> tag within <td> tag
                name_list_wbc.append(anchor_tag.text.strip())
            except:
                name_list_wbc.append(td_tag.text.strip())

# %%
name_list_wbc[-1]
# Out:
# 'Yudai Shigeoka'

# %% [markdown]
# WBO

# %%
name_list_wbo = []
r = requests.get('https://en.wikipedia.org/wiki/List_of_WBO_world_champions')
soup = BeautifulSoup(r.text, 'html.parser')
for table in soup.find_all('table'):
    for row in table.find_all('tr'):
        td_tag = row.find('td', align='left')  # Find <td> tag with align="left"
        if td_tag: 
            try:
                anchor_tag = td_tag.find('a')  # Find <a> tag within <td> tag
                name_list_wbo.append(anchor_tag.text.strip())
            except:
                name_list_wbo.append(td_tag.text.strip())

# %%
name_list_wbo[-1]
# Out:
# 'Oscar Collazo'

# %% [markdown]
# The Ring

# %%
name_list_thering = []
r = requests.get('https://en.wikipedia.org/wiki/List_of_The_Ring_world_champions')
soup = BeautifulSoup(r.text, 'html.parser')
for table in soup.find_all('table'):
    for row in table.find_all('tr'):
        td_tag = row.find('td', align='left')  # Find <td> tag with align="left"
        if td_tag:
            try:
                anchor_tag = td_tag.find('a')  # Find <a> tag within <td> tag
                name_list_thering.append(anchor_tag.text.strip())
            except:
                name_list_thering.append(td_tag.text.strip())

# %%
name_list_thering[0]
# Out:
# 'Jack Dempsey'

# %% [markdown]
# IBF

# %%
name_list_IBF = []
r = requests.get('https://en.wikipedia.org/wiki/List_of_IBF_world_champions')
soup = BeautifulSoup(r.text, 'html.parser')
for table in soup.find_all('table'):
    for row in table.find_all('tr'):
        td_tag = row.find('td', align='left')  # Find <td> tag with align="left"
        if td_tag:
            try:
                anchor_tag = td_tag.find('a')  # Find <a> tag within <td> tag
                name_list_IBF.append(anchor_tag.text.strip())
            except:
                name_list_IBF.append(td_tag.text.strip())

# %%
name_list_IBF[0]
# Out:
# 'Larry Holmes'

# %% [markdown]
# IBO

# %%
name_list_IBO = []
r = requests.get('https://en.wikipedia.org/wiki/List_of_IBO_world_champions')
soup = BeautifulSoup(r.text, 'html.parser')
for table in soup.find_all('table'):
    for row in table.find_all('tr'):
        td_tag = row.find('td', align='left')
        if td_tag:
            anchor_tag = td_tag.find_all('a')
            try:
                name_list_IBO.append(anchor_tag[1].text.strip())
            except:
                name_list_IBO.append(td_tag.text.strip())

# %%
len(name_list_IBO)
# Out:
# 294

# %% [markdown]
# W-IBF

# %%
name_list_W_IBF = []
r = requests.get('https://en.wikipedia.org/wiki/List_of_IBF_female_world_champions')
soup = BeautifulSoup(r.text, 'html.parser')
for table in soup.find_all('table'):
    for row in table.find_all('tr'):
        td_tag = row.find('td', align='left')
        if td_tag:
            anchor_tag = td_tag.find_all('a')
            try:
                name_list_W_IBF.append(anchor_tag[1].text.strip())
            except:
                name_list_W_IBF.append(td_tag.text.strip())

# %%
name_list_W_IBF.append('Evelyn Nazarena Bermúdez')

# %% [markdown]
# W-WBA

# %%
name_list_W_WBA = []
r = requests.get('https://en.wikipedia.org/wiki/List_of_WBA_female_world_champions')
soup = BeautifulSoup(r.text, 'html.parser')
for table in soup.find_all('table'):
    for row in table.find_all('tr'):
        td_tag = row.find('td', align='left')
        if td_tag:
            anchor_tag = td_tag.find_all('a')
            try:
                name_list_W_WBA.append(anchor_tag[1].text.strip())
            except:
                name_list_W_WBA.append(td_tag.text.strip())

# %% [markdown]
# W_WBC

# %%
name_list_W_WBC = []
r = requests.get('https://en.wikipedia.org/wiki/List_of_WBC_female_world_champions')
soup = BeautifulSoup(r.text, 'html.parser')
for table in soup.find_all('table'):
    for row in table.find_all('tr'):
        td_tag = row.find('td', align='left')
        if td_tag:
            anchor_tag = td_tag.find_all('a')
            try:
                name_list_W_WBC.append(anchor_tag[1].text.strip())
            except:
                name_list_W_WBC.append(td_tag.text.strip())

# %% [markdown]
# W_WBO

# %%
name_list_W_WBO = []
r = requests.get('https://en.wikipedia.org/wiki/List_of_WBO_female_world_champions')
soup = BeautifulSoup(r.text, 'html.parser')
for table in soup.find_all('table'):
    for row in table.find_all('tr'):
        td_tag = row.find('td', align='left')
        if td_tag:
            anchor_tag = td_tag.find_all('a')
            try:
                name_list_W_WBO.append(anchor_tag[1].text.strip())
            except:
                name_list_W_WBO.append(td_tag.text.strip())

# %%
print('yes' if 'vacant' in name_list_W_WBO else 'no')
#name_list_W_WBO.pop()
# Out:
# yes

# %% [markdown]
# W_IBO

# %%
name_list_W_IBO = []
r = requests.get('https://en.wikipedia.org/wiki/List_of_IBO_female_world_champions')
soup = BeautifulSoup(r.text, 'html.parser')
for table in soup.find_all('table'):
    for row in table.find_all('tr'):
        td_tag = row.find('td', align='left')
        if td_tag:
            anchor_tag = td_tag.find_all('a')
            try:
                name_list_W_IBO.append(anchor_tag[1].text.strip())
            except:
                name_list_W_IBO.append(td_tag.text.strip())

# %%
print('yes' if 'vacant' in name_list_W_IBO else 'no')
#name_list_W_IBO.remove('vacant')
# Out:
# yes

# %% [markdown]
# W_THE_RING

# %%
name_list_W_thering = []
r = requests.get('https://en.wikipedia.org/wiki/List_of_The_Ring_female_world_champions')
soup = BeautifulSoup(r.text, 'html.parser')
for table in soup.find_all('table'):
    for row in table.find_all('tr'):
        td_tag = row.find('td', align='left')
        if td_tag:
            anchor_tag = td_tag.find_all('a')
            try:
                name_list_W_thering.append(anchor_tag[1].text.strip())
            except:
                name_list_W_thering.append(td_tag.text.strip())

# %%
name_list_W_thering
# Out:
# ['Franchón Crews-Dezurn',
#  'Savannah Marshall',
#  'Claressa Shields',
#  'Claressa Shields',
#  'Jessica McCaskill',
#  'Chantelle Cameron',
#  'Katie Taylor',
#  'Katie Taylor',
#  'Mikaela Mayer',
#  'Alycia Baumgardner',
#  'Amanda Serrano',
#  'Dina Thorslund',
#  'Marlen Esparza',
#  'Seniesa Estrada']

# %%
all_names = name_list_W_thering + name_list_W_IBO + name_list_W_WBO + name_list_W_WBC + name_list_W_WBA+ name_list_W_IBF + name_list_IBO + name_list_IBF + name_list_thering + name_list_wbo + name_list_wbc + name_list

# %%
len(set(all_names))
# Out:
# 2236

# %%
df = pd.DataFrame(columns=['Name'])

# %%
df['Name'] = all_names

# %%
name_lists = name_list_IBO + name_list_IBF + name_list_thering + name_list_wbo + name_list_wbc + name_list

# %%
f_names = [x for x in all_names if x not in name_lists]
print(f_names)
# Out:
# ['Franchón Crews-Dezurn', 'Savannah Marshall', 'Claressa Shields', 'Claressa Shields', 'Jessica McCaskill', 'Chantelle Cameron', 'Katie Taylor', 'Katie Taylor', 'Mikaela Mayer', 'Alycia Baumgardner', 'Amanda Serrano', 'Dina Thorslund', 'Marlen Esparza', 'Seniesa Estrada', 'Zongju Cai', 'Sarah Bormann', 'vacant', 'Nina Radovanović', 'Gloria Gallardo', 'Eva Voraberger', 'Esmeralda Moreno', 'Eva Voraberger (2)', 'Daniela Asenjo', 'Sharadene Fortuin', 'Melissa Oddessa Parker', 'Vissia Trovato', 'Ségolène Lefebvre', 'Mea Motu', 'Iwona Guzowska', 'Licia Boudersa', 'Amanda Serrano', 'Firuza Sharipova', 'Terri Harper', 'Alycia Baumgardner', 'Chantelle Cameron', 'Estelle Yoka Mossely', 'Lucia Rijker', 'Agnieszka Rylik', 'Esther Phiri', 'Svetlana Kulakova', 'Kali Reis', 'Chantelle Cameron', 'Katie Taylor', 'Jennifer Retzke', 'Cecilia Braekhus', 'Jessica McCaskill', 'Mikaela Laurén', 'Hannah Rankin', 'Patricia Berghult', 'Hannah Rankin (2)', 'Terri Harper', 'Ivana Habazin', 'vacant', 'vacant', 
# ...

# %%
print("len of allnames is{} females is {} niggas is {}".format(len(all_names),len(f_names),len(name_lists)))
# Out:
# len of allnames is3664 females is 470 niggas is 3194

# %%
df.shape
# Out:
# (3664, 1)

# %%
df['Name'].value_counts()
#df.shape
# Out:
# Name
# Canelo Álvarez          15
# Naoya Inoue             13
# Floyd Mayweather Jr.    13
# Claressa Shields        12
# Manny Pacquiao          12
#                         ..
# Yésica Bopp              1
# Walter McGowan           1
# Susi Kentikian (2)       1
# Ha-Na Kim                1
# Erick Rosa               1
# Name: count, Length: 2236, dtype: int64

# %%
df_clean = df.drop_duplicates(ignore_index = True)

# %%
df_clean.shape
# Out:
# (2236, 1)

# %%
df_clean.value_counts()
# Out:
# Name
#                     1
# Nana Konadu (2)     1
# Myung Ok Ryu        1
# Myung Ok Ryu (2)    1
# Mzonke Fana         1
#                    ..
# Herbie Hide         1
# Henry Maske         1
# Henry Armstrong     1
# Henry Akinwande     1
# Óscar Valdez        1
# Name: count, Length: 2236, dtype: int64

# %%
print([a for a in df_clean['Name'] if ('(') in a])
# Out:
# ['Eva Voraberger (2)', 'Hannah Rankin (2)', 'Teeraporn Pannimit (2)', 'Melissa McMorrow (2)', 'Ana Julaton (2)', 'Amanda Serrano (2) (elevated to Super champion on 19 Feb 2020)', 'Fernanda Soledad Alegre (2)', 'Christina Linardatou (2)', 'Katie Taylor (2)', 'Hanna Gabriels (2)', 'Claressa Shields (2)', 'Myung Ok Ryu (2)', 'Ana María Torres (2) - Interim champion promoted', 'Anita Christensen (2) - Interim champion promoted', 'Jackie Nava (2)', 'Alicia Ashley (2)', 'Jelena Mrdjenovich (2)', 'Jelena Mrdjenovich (3)', 'Jessica Rakoczy (2)', 'Ann Saccurato (2)', 'Ann Saccurato (3)', 'Susi Kentikian (2)', 'Liliana Palmera (2)', 'Cecilia Comunales (2)', 'Nancy Franco (2)', 'Claudia Andrea López (2)', 'Lennox Lewis (2)', 'Anthony Joshua (2)', 'Carl Thompson (2)', 'Danny Green (2)', 'Ola Afolabi (2)', 'Antonio Tarver (2)', 'Antonio Tarver (3)', 'Dominic Boesel (2)', 'Raymond Joval (2)', 'Gennady Golovkin (2)', 'Zaurbek Baysangurov (2)', 'Israel Cardona (2)', 'Cassius Baloyi (2)', 'Silence Ma
# ...

# %%
type('abc'.split(' ')[0])
# Out:
# str

# %%
# Filter the DataFrame to get rows where the 'Name' column contains the symbol \
mask = df_clean['Name'].str.contains('\(')
#print(mask)
df_clean = df_clean[~mask]
#rows_with_parens['Name'] = rows_with_parens['Name'].str.split('(').str[0] 
#rows_with_parens['Name'] = rows_with_parens['Name'].str.split('(').str[0]
# Modify the values containing the letter (for example, converting to uppercase)
#df_clean.loc[df_clean.index.isin(rows_with_parens.index), 'Name'] = rows_with_parens['Name']
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2231    False
# 2232    False
# 2233    False
# 2234     True
# 2235    False
# Name: Name, Length: 2236, dtype: bool

# %%
df_clean['Name'].str.contains('Felix Sturm').any()
# Out:
# True

# %%
df_clean.tail(20)
# Out:
#                                     Name
# 2211            Pichitnoi Sitbangprachan
# 2212                      Beibis Mendoza
# 2213                     Roberto Vásquez
# 2214                       Brahim Asloum
# 2217                      Alberto Rossel
# 2218  Kenshiro Teraji – Unified champion
# 2219                    Carlos Cañizales
# 2220                    Esteban Bermudez
# 2221                        Kim Bong-jun
# 2222                      Chana Porpaoin
# 2223                      Noel Arambulet
# 2224                         Joma Gamboa
# 2225                     Keitaro Hoshino
# 2227                        Yutaka Niida
# 2229                Kwanthai Sithmorseng
# 2230                Pornsawan Porpramook
# 2231                        Ryo Miyazaki
# 2232                         Byron Rojas
# 2233               Knockout CP Freshmart
# 2235                          Erick Rosa

# %%
df_clean = df_clean.drop(df_clean[df_clean['Name'] == 'vacant'].index)

# %%
import numpy as np

name_lists = name_list_IBO + name_list_IBF + name_list_thering + name_list_wbo + name_list_wbc + name_list

#df_clean['Sex'] = np.where(df_clean['Name'].isin(name_lists), 'M', 'F')
df_clean['Sex'] = np.where(df_clean['Name'].isin(name_lists), 'M', 'F')

# %%
df_clean.tail(10)
# Out:
#                        Name Sex
# 2223         Noel Arambulet   M
# 2224            Joma Gamboa   M
# 2225        Keitaro Hoshino   M
# 2227           Yutaka Niida   M
# 2229   Kwanthai Sithmorseng   M
# 2230   Pornsawan Porpramook   M
# 2231           Ryo Miyazaki   M
# 2232            Byron Rojas   M
# 2233  Knockout CP Freshmart   M
# 2235             Erick Rosa   M

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from time import sleep

# %%
#chrome_user_data_dir = 'C:\\Users\\HP\\AppData\\Local\\Google\\Chrome\\User Data'
#chrome_options = webdriver.ChromeOptions()

# Add the user data directory to Chrome options
#chrome_options.add_argument(f"user-data-dir={chrome_user_data_dir}")

# %%
# Pass Chrome options to the WebDriver
#driver = webdriver.Chrome(options=chrome_options)
# Navigate to the website
'''
driver.get('https://boxrec.com/en/login')
driver.maximize_window()
sleep(1)
driver.find_element(By.ID,'username').send_keys('abidimohamedaziz7777777@gmail.com')
sleep(1)
driver.find_element(By.ID,'password').send_keys('ik@EC4zh8@Jgeaz')
sleep(1)
driver.find_element(By.CLASS_NAME,'submitButton').click()
sleep(5) 
input_box = driver.find_element(By.ID,"si_search_text")
input_box.send_keys('Óscar Larios')
sleep(1)
input_box.send_keys(Keys.RETURN)
sleep(2)
fighter_name = driver.find_element(By.XPATH,"//*[@id='se0']/td[1]/a")
fighter_name.click()
page = BeautifulSoup(driver.page_source, 'html.parser')'''
# Out:
# '\ndriver.get(\'https://boxrec.com/en/login\')\ndriver.maximize_window()\nsleep(1)\ndriver.find_element(By.ID,\'username\').send_keys(\'abidimohamedaziz7777777@gmail.com\')\nsleep(1)\ndriver.find_element(By.ID,\'password\').send_keys(\'ik@EC4zh8@Jgeaz\')\nsleep(1)\ndriver.find_element(By.CLASS_NAME,\'submitButton\').click()\nsleep(5) \ninput_box = driver.find_element(By.ID,"si_search_text")\ninput_box.send_keys(\'Óscar Larios\')\nsleep(1)\ninput_box.send_keys(Keys.RETURN)\nsleep(2)\nfighter_name = driver.find_element(By.XPATH,"//*[@id=\'se0\']/td[1]/a")\nfighter_name.click()\npage = BeautifulSoup(driver.page_source, \'html.parser\')'

# %%
df_clean.reset_index(inplace=True, drop=True)

# %%
df_clean['Name'] = df_clean['Name'].str.strip()

# %%
df_clean.drop(df_clean.loc[df_clean['Name'].str.contains(' –')].index, inplace=True)

# %%
df_clean.head(20)
# Out:
#                      Name Sex
# 0   Franchón Crews-Dezurn   F
# 1       Savannah Marshall   F
# 2        Claressa Shields   F
# 3       Jessica McCaskill   F
# 4       Chantelle Cameron   F
# 5            Katie Taylor   F
# 6           Mikaela Mayer   F
# 7      Alycia Baumgardner   F
# 8          Amanda Serrano   F
# 9          Dina Thorslund   F
# 10         Marlen Esparza   F
# 11        Seniesa Estrada   F
# 12             Zongju Cai   F
# 13          Sarah Bormann   F
# 14       Nina Radovanović   F
# 15        Gloria Gallardo   F
# 16         Eva Voraberger   F
# 17       Esmeralda Moreno   F
# 18         Daniela Asenjo   F
# 19      Sharadene Fortuin   F

# %%
options = webdriver.ChromeOptions()
options.add_extension('uBlock_Origin.crx') 

# Add any other options you need, for example:
# options.add_argument('--disable-extensions')  # Disable other extensions

# %%
data = []

# %%
driver = webdriver.Chrome(options=options)
driver.get("https://en.wikipedia.org/wiki/Main_Page")
driver.maximize_window()

data = []  # List to store scraped data

for name in df_clean['Name']:
    try:   
        input_box = driver.find_element(By.CLASS_NAME, "cdx-text-input__input")
        input_box.clear()
        input_box.send_keys(name)
        sleep(1)
        input_box = driver.find_element(By.CLASS_NAME, "cdx-text-input__input") 
        input_box.send_keys(Keys.ENTER)
        # Wait until the infobox appears
        WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.CLASS_NAME, "infobox")))
        #sleep(2)
        html_boxer = BeautifulSoup(driver.page_source, 'html.parser')
        big_t = html_boxer.find('table', class_="infobox")
        
        # Extract data if boxer page is found
        birthday = None
        nationality = None
        weight = None
        height = None
        reach = None
        stance = None
        total_fights = None
        wins = None
        wins_by_ko = None
        losses = None
        draws = None
        no_contests = None
        
        rows = big_t.find_all('tr')
        
        for row in rows:
            if row.find('th') is None:
                pass
            elif row.find('th').text.strip() == "Born":
                try:
                    birthday = row.find('span', class_="bday").text.strip()
                    nationality = row.find('div', class_="birthplace").text.strip()
                except:
                    pass
            elif row.find('th').text.strip() == "Weight(s)" or row.find('th').text.strip() == "Division":
                try:
                    weightinfo = row.find('td', class_="infobox-data")
                    weight = '/'.join(wei.get_text().strip() for wei in weightinfo.find_all('a'))
                except:
                    pass
            elif row.find('th').text.strip() == "Height":
                try:
                    height = row.find('td', class_="infobox-data").text.strip()
                except:
                    pass
            elif row.find('th').text.strip() == "Reach":
                try:
                    reach = row.find('td', class_="infobox-data").text.strip()
                except:
                    pass
            elif row.find('th').text.strip() == "Stance":
                try:
                    stan = row.find('td', class_="infobox-data")
                    stance = stan.find('a').text.strip()
                except:
                    pass
            elif row.find('th').text.strip() == "Total fights":
                try:
                    total_fights = row.find('td', class_="infobox-data").text.strip()
                except:
                    pass
                
            elif row.find('th').text.strip() == "Wins":
                try:
                    wins = row.find('td', class_="infobox-data").text.strip()
                except:
                    pass
            elif row.find('th').text.strip() == "Wins by KO":
                try:
                    wins_by_ko = row.find('td', class_="infobox-data").text.strip()
                except:
                    pass
            elif row.find('th').text.strip() == "Losses":
                try:
                    losses = row.find('td', class_="infobox-data").text.strip()
                except:
                    pass
            elif row.find('th').text.strip() == "Draws":
                try:
                    draws = row.find('td', class_="infobox-data").text.strip()
                except:
                    pass
            elif row.find('th').text.strip() == "No contests":
                try:
                    no_contests = row.find('td', class_="infobox-data").text.strip()
                except:
                    pass
                
        data.append({
            'Name': name,
            'Birthday': birthday,
            'Nationality': nationality,
            'Weight': weight,
            'Height': height,
            'Reach': reach,
            'Stance': stance,
            'Total Fights': total_fights,
            'Wins': wins,
            'Wins by KO': wins_by_ko,
            'Losses': losses,
            'Draws': draws,
            'No Contests': no_contests
        })
        sleep(1)
        
    except Exception as e:
         print(e)
         data.append({
                'Name': name,
                'Birthday': None,
                'Nationality': None,
                'Weight': None,
                'Height': None,
                'Reach': None,
                'Stance': None,
                'Total Fights': None,
                'Wins': None,
                'Wins by KO': None,
                'Losses': None,
                'Draws': None,
                'No Contests': None
            })

# Create DataFrame from scraped data

df_final = pd.DataFrame(data)
# Out:
# Message: stale element reference: stale element not found
#   (Session info: chrome=122.0.6261.95); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#stale-element-reference-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7381AAD22+56930]
# 	(No symbol) [0x00007FF73811F622]
# 	(No symbol) [0x00007FF737FD42E5]
# 	(No symbol) [0x00007FF737FD9261]
# 	(No symbol) [0x00007FF737FDB6EB]
# 	(No symbol) [0x00007FF737FDB7B0]
# 	(No symbol) [0x00007FF738014AAA]
# 	(No symbol) [0x00007FF738013662]
# 	(No symbol) [0x00007FF73803BC9A]
# 	(No symbol) [0x00007FF73800F09A]
# 	(No symbol) [0x00007FF73803BEB0]
# 	(No symbol) [0x00007FF7380581E2]
# 	(No symbol) [0x00007FF73803BA43]
# 	(No symbol) [0x00007FF73800D438]
# 	(No symbol) [0x00007FF73800E4D1]
# 	GetHandleVerifier [0x00007FF738526AAD+3709933]
# 	GetHandleVerifier [0x00007FF73857FFED+4075821]
# 	GetHandleVerifier [0x00007FF73857817F+4043455]
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          1949 non-null   object
#  1   Birthday      1449 non-null   object
#  2   Nationality   1384 non-null   object
#  3   Weight        1454 non-null   object
#  4   Height        1310 non-null   object
#  5   Reach         927 non-null    object
#  6   Stance        1275 non-null   object
#  7   Total Fights  1442 non-null   object
#  8   Wins          1477 non-null   object
#  9   Wins by KO    1440 non-null   object
#  10  Losses        1436 non-null   object
#  11  Draws         922 non-null    object
#  12  No Contests   363 non-null    object
# dtypes: object(13)
# memory usage: 198.1+ KB

# %%
"""driver=webdriver.Chrome()
driver.get("https://en.wikipedia.org/wiki/Main_Page")
for name in df_clean['Name']:
    try:   
        input_box = driver.find_element(By.CLASS_NAME,"cdx-text-input__input")
        input_box.send_keys(name)
        input_box.send_keys(Keys.ENTER)
        html_boxer = BeautifulSoup(driver.page_source, 'html.parser')
        big_t = html_boxer.find('table', class_="infobox")
        rows = big_t.find_all('tr')
        for row in rows:
            if row.find('th') is None:
                continue
            elif row.find('th').text.strip() == "Born":
                birthday = row.find('span', class_="bday").text.strip()
                nationality = row.find('div', class_="birthplace").text.strip()
            elif row.find('th').text.strip() == "Weight(s)":
                weightinfo = row.find('td', class_="infobox-data")
                weight = '/'.join(wei.get_text().strip() for wei in weightinfo.find_all('a'))
            elif row.find('th').text.strip() == "Height":
                height = row.find('td', class_="infobox-data").text.strip()
            elif row.find('th').text.strip() == "Reach":
                reach = row.find('td', class_="infobox-data").text.strip()
            elif row.find('th').text.strip() == "Stance":
                stan = row.find('td', class_="infobox-data")
                stance = stan.find('a').text.strip()
            elif row.find('th').text.strip() == "Total fights":
                total_figths = row.find('td', class_="infobox-data").text.strip()
            elif row.find('th').text.strip() == "Wins":
                wins = row.find('td', class_="infobox-data").text.strip()
            elif row.find('th').text.strip() == "Wins by KO":
                wins_by_ko = row.find('td', class_="infobox-data").text.strip()
            elif row.find('th').text.strip() == "Losses":
                losses = row.find('td', class_="infobox-data").text.strip()
            elif row.find('th').text.strip() == "Draws":
                draws = row.find('td', class_="infobox-data").text.strip()
            elif row.find('th').text.strip() == "No contests":
                No_contests = row.find('td', class_="infobox-data").text.strip()
    except:
        pass
            
      """
# Out:
# 'driver=webdriver.Chrome()\ndriver.get("https://en.wikipedia.org/wiki/Main_Page")\nfor name in df_clean[\'Name\']:\n    try:   \n        input_box = driver.find_element(By.CLASS_NAME,"cdx-text-input__input")\n        input_box.send_keys(name)\n        input_box.send_keys(Keys.ENTER)\n        html_boxer = BeautifulSoup(driver.page_source, \'html.parser\')\n        big_t = html_boxer.find(\'table\', class_="infobox")\n        rows = big_t.find_all(\'tr\')\n        for row in rows:\n            if row.find(\'th\') is None:\n                continue\n            elif row.find(\'th\').text.strip() == "Born":\n                birthday = row.find(\'span\', class_="bday").text.strip()\n                nationality = row.find(\'div\', class_="birthplace").text.strip()\n            elif row.find(\'th\').text.strip() == "Weight(s)":\n                weightinfo = row.find(\'td\', class_="infobox-data")\n                weight = \'/\'.join(wei.get_text().strip() for wei in weightinfo.find_all(\'a\
# ...

# %%
r = requests.get("https://en.wikipedia.org/wiki/Mea_Motu")
sou_tst = BeautifulSoup(r.text, 'html.parser')
#print(sou_tst.prettify())

# %%
big_t = sou_tst.find('table', class_="infobox")
rows = big_t.find_all('tr')
for row in rows:
    if row.find('th') is None:
        continue
    elif row.find('th').text.strip() == "Born":
        birthday = row.find('span', class_="bday").text.strip()
        nationality = row.find('div', class_="birthplace").text.strip()
    elif row.find('th').text.strip() == "Weight(s)":
        weightinfo = row.find('td', class_="infobox-data")
        weight = '/'.join(wei.get_text().strip() for wei in weightinfo.find_all('a'))
    elif row.find('th').text.strip() == "Height":
        height = row.find('td', class_="infobox-data").text.strip()
    elif row.find('th').text.strip() == "Reach":
        reach = row.find('td', class_="infobox-data").text.strip()
    elif row.find('th').text.strip() == "Stance":
        stan = row.find('td', class_="infobox-data")
        stance = stan.find('a').text.strip()
    elif row.find('th').text.strip() == "Total fights":
        total_figths = row.find('td', class_="infobox-data").text.strip()
    elif row.find('th').text.strip() == "Wins":
        wins = row.find('td', class_="infobox-data").text.strip()
    elif row.find('th').text.strip() == "Wins by KO":
        wins_by_ko = row.find('td', class_="infobox-data").text.strip()
    elif row.find('th').text.strip() == "Losses":
        losses = row.find('td', class_="infobox-data").text.strip()
    elif row.find('th').text.strip() == "Draws":
        draws = row.find('td', class_="infobox-data").text.strip()
    elif row.find('th').text.strip() == "No contests":
        No_contests = row.find('td', class_="infobox-data").text.strip()

boxer_data = {'Birthday': birthday, 'Nationality': nationality, 'Weight': weight, 'Height': height, 'Reach': reach, 'Stance':stance,
                    'total_figths': total_figths, 'Wins': wins, 'Wins by KO': wins_by_ko, 'Losses': losses, 'deaws': draws}
    
for key, value in boxer_data.items():
    print(f"{key}: {value}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 7
#       5     continue
#       6 elif row.find('th').text.strip() == "Born":
# ----> 7     birthday = row.find('span', class_="bday").text.strip()
#       8     nationality = row.find('div', class_="birthplace").text.strip()
#       9 elif row.find('th').text.strip() == "Weight(s)":
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
df_final.columns
# Out:
# Index(['Name', 'Birthday', 'Nationality', 'Weight', 'Height', 'Reach',
#        'Stance', 'Total Fights', 'Wins', 'Wins by KO', 'Losses', 'Draws',
#        'No Contests'],
#       dtype='object')

# %%
df_recheck = df_final[(df_final[['Birthday', 'Nationality', 'Weight', 'Height', 'Reach', 'Stance', 'Total Fights', 'Wins', 'Wins by KO', 'Losses', 'Draws', 'No Contests']].isnull().all(axis=1)) & (~df_final['Name'].isnull())]

# %%
df_recheck
# Out:
#                    Name Birthday Nationality Weight Height Reach Stance  \
# 3     Jessica McCaskill     None        None   None   None  None   None
# 12           Zongju Cai     None        None   None   None  None   None
# 13        Sarah Bormann     None        None   None   None  None   None
# 16       Eva Voraberger     None        None   None   None  None   None
# 18       Daniela Asenjo     None        None   None   None  None   None
# ...                 ...      ...         ...    ...    ...   ...    ...
# 1920       Pedro Flores     None        None   None   None  None   None
# 1923        Lupe Madera     None        None   None   None  None   None
# 1924   Francisco Quiróz     None        None   None   None  None   None
# 1928     Carlos Murillo     None        None   None   None  None   None
# 1929    Keiji Yamaguchi     None        None   None   None  None   None
#
#      Total Fights  Wins Wins by KO Losses Draws No Contests
# ...

# %%
driver = webdriver.Chrome(options=options)
driver.get("https://en.wikipedia.org/wiki/Main_Page")
driver.maximize_window()

data = []  # List to store scraped data

for name in df_recheck['Name']:
    try:   
        input_box = driver.find_element(By.CLASS_NAME, "cdx-text-input__input")
        input_box.clear()
        input_box.send_keys(name)
        sleep(1)
        input_box = driver.find_element(By.CLASS_NAME, "cdx-text-input__input") 
        input_box.send_keys(Keys.ENTER)
        # Wait until the infobox appears
        WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.CLASS_NAME, "infobox")))
        #sleep(2)
        html_boxer = BeautifulSoup(driver.page_source, 'html.parser')
        big_t = html_boxer.find('table', class_="infobox")
        
        # Extract data if boxer page is found
        birthday = None
        nationality = None
        weight = None
        height = None
        reach = None
        stance = None
        total_fights = None
        wins = None
        wins_by_ko = None
        losses = None
        draws = None
        no_contests = None
        
        rows = big_t.find_all('tr')
        
        for row in rows:
            if row.find('th') is None:
                pass
            elif row.find('th').text.strip() == "Born":
                try:
                    birthday = row.find('span', class_="bday").text.strip()
                    nationality = row.find('div', class_="birthplace").text.strip()
                except:
                    pass
            elif row.find('th').text.strip() == "Weight(s)" or row.find('th').text.strip() == "Division":
                try:
                    weightinfo = row.find('td', class_="infobox-data")
                    weight = '/'.join(wei.get_text().strip() for wei in weightinfo.find_all('a'))
                except:
                    pass
            elif row.find('th').text.strip() == "Height":
                try:
                    height = row.find('td', class_="infobox-data").text.strip()
                except:
                    pass
            elif row.find('th').text.strip() == "Reach":
                try:
                    reach = row.find('td', class_="infobox-data").text.strip()
                except:
                    pass
            elif row.find('th').text.strip() == "Stance":
                try:
                    stan = row.find('td', class_="infobox-data")
                    stance = stan.find('a').text.strip()
                except:
                    pass
            elif row.find('th').text.strip() == "Total fights":
                try:
                    total_fights = row.find('td', class_="infobox-data").text.strip()
                except:
                    pass
                
            elif row.find('th').text.strip() == "Wins":
                try:
                    wins = row.find('td', class_="infobox-data").text.strip()
                except:
                    pass
            elif row.find('th').text.strip() == "Wins by KO":
                try:
                    wins_by_ko = row.find('td', class_="infobox-data").text.strip()
                except:
                    pass
            elif row.find('th').text.strip() == "Losses":
                try:
                    losses = row.find('td', class_="infobox-data").text.strip()
                except:
                    pass
            elif row.find('th').text.strip() == "Draws":
                try:
                    draws = row.find('td', class_="infobox-data").text.strip()
                except:
                    pass
            elif row.find('th').text.strip() == "No contests":
                try:
                    no_contests = row.find('td', class_="infobox-data").text.strip()
                except:
                    pass
                
        data.append({
            'Name': name,
            'Birthday': birthday,
            'Nationality': nationality,
            'Weight': weight,
            'Height': height,
            'Reach': reach,
            'Stance': stance,
            'Total Fights': total_fights,
            'Wins': wins,
            'Wins by KO': wins_by_ko,
            'Losses': losses,
            'Draws': draws,
            'No Contests': no_contests
        })
        
        
    except Exception as e:
         print(e)
         data.append({
                'Name': name,
                'Birthday': None,
                'Nationality': None,
                'Weight': None,
                'Height': None,
                'Reach': None,
                'Stance': None,
                'Total Fights': None,
                'Wins': None,
                'Wins by KO': None,
                'Losses': None,
                'Draws': None,
                'No Contests': None
            })

# Create DataFrame from scraped data

df_final_2 = pd.DataFrame(data)
# Out:
# Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7381AAD22+56930]
# 	(No symbol) [0x00007FF73811F622]
# 	(No symbol) [0x00007FF737FD42E5]
# 	(No symbol) [0x00007FF7380198ED]
# 	(No symbol) [0x00007FF738019A2C]
# 	(No symbol) [0x00007FF73805A967]
# 	(No symbol) [0x00007FF73803BCDF]
# 	(No symbol) [0x00007FF7380581E2]
# 	(No symbol) [0x00007FF73803BA43]
# 	(No symbol) [0x00007FF73800D438]
# 	(No symbol) [0x00007FF73800E4D1]
# 	GetHandleVerifier [0x00007FF738526AAD+3709933]
# 	GetHandleVerifier [0x00007FF73857FFED+4075821]
# 	GetHandleVerifier [0x00007FF73857817F+4043455]
# 	GetHandleVerifier [0x00007FF738249756+706710]
# 	(No symbol) [0x00007FF73812B8FF]
# 	(No symbol) [0x00007FF738126AE4]
# 	(No symbol) [0x00007FF738126C3C]
# 	(No symbol) [0x00007FF7381168F4]
# 	BaseThreadInitThunk [0x00007FFF56907344+20]
# 	RtlUserThreadStart [0x00007FFF574426B1+33]
#
# Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7381AAD22+56930]
# 	(No symbol) [0x00007FF73811F622]
# ...

# %%
data = []

# %%
df_final_2[df_final_2['Name'] == 'Amir Khan']
# Out:
#           Name    Birthday                          Nationality  \
# 240  Amir Khan  1986-12-08  Bolton, Greater Manchester, England
#
#                                                 Weight  \
# 240  Lightweight/Light-welterweight/Welterweight/Mi...
#
#                        Height              Reach    Stance Total Fights Wins  \
# 240  5 ft 81⁄2 in (174 cm)[1]  71 in (180 cm)[1]  Orthodox           40   34
#
#     Wins by KO Losses Draws No Contests
# 240         21      6  None        None

# %%
#need to add         carlos murillo

# %%
df_final_2.loc[df_final_2['Name'].str.contains('Barry Jones'),['Birthday','Nationality'	,'Weight','Height','Reach','Stance','Total Fights','Wins','Wins by KO','Losses','Draws','No Contests']]  = 'British'

# %%
df_final_2.loc[df_final_2['Name'].str.contains('Carlos Murillo'),['Birthday','Nationality','Weight','Height','Reach','Stance','Total Fights','Wins','Wins by KO','Losses','Draws','No Contests']]  = ['1970-12-10','Panama', 'flyweight', '155cm ','160 cm', 'Orthodox',50,38,29,11,1,None]

# %%
df_final_2.columns
# Out:
# Index(['Name', 'Birthday', 'Nationality', 'Weight', 'Height', 'Reach',
#        'Stance', 'Total Fights', 'Wins', 'Wins by KO', 'Losses', 'Draws',
#        'No Contests'],
#       dtype='object')

# %%
df_final_2.to_csv('df_better_final_2.csv')

# %%
final_ds = pd.concat([df_final, df_final_2], ignore_index=True)

# %%
final_ds.head(10)
# Out:
#                      Name    Birthday                     Nationality  \
# 0   Franchón Crews-Dezurn  1987-06-13  Virginia Beach, Virginia, U.S.
# 1       Savannah Marshall  1991-05-19             Hartlepool, England
# 2        Claressa Shields  1995-03-17                            None
# 4       Chantelle Cameron  1991-05-14            Northampton, England
# 5            Katie Taylor  1986-07-02   Bray, County Wicklow, Ireland
# 6           Mikaela Mayer  1990-07-04   Los Angeles, California, U.S.
# 7      Alycia Baumgardner  1994-05-24             Fremont, Ohio, U.S.
# 8          Amanda Serrano  1988-10-09           Carolina, Puerto Rico
# 9          Dina Thorslund  1993-10-14             Copenhagen, Denmark
# 10         Marlen Esparza  1989-07-29           Pasadena, Texas, U.S.
#
#                                                Weight  \
# 0                                  Super middleweight
# 1                     Middleweight/Super-middleweight
# ...

# %%
# Merge the two DataFrames on the 'Name' column, including only rows from df2
final_ds.drop_duplicates(subset=['Name'], keep='last', inplace=True)

# %%
final_ds['Sex'] = np.where(final_ds['Name'].isin(name_lists), 'M', 'F')

# %%
final_ds['Sex'].value_counts()
# Out:
# Sex
# M    1688
# F     261
# Name: count, dtype: int64

# %%
final_ds.isna().sum()
# Out:
# Name               0
# Birthday         332
# Nationality      405
# Weight           327
# Height           486
# Reach            912
# Stance           527
# Total Fights     342
# Wins             304
# Wins by KO       345
# Losses           352
# Draws            928
# No Contests     1549
# Sex                0
# dtype: int64

# %%
final_ds.to_csv('final_data.csv')

# %%
import re

# %%
# Apply the function to extract height in centimeters for each row
#final_ds['Height_cm'] = final_ds['Height'].str.split('m')[0]
def msplit(x):
    try:
        return x.split('m')[0]
    except:
        return x
def othersplits(x):
    try:
        return x.split('(')[1]
    except:
        return x

final_ds['Height_cm'] = final_ds['Height'].apply(msplit)
final_ds['Height_cm'] = final_ds['Height_cm'].apply(othersplits)

# %%
final_ds['Height_cm'] = final_ds['Height_cm'].str.replace('.', '')

# %%
#final_ds['Height_cm'].dropna().str.contains("'")
print(final_ds_filled[final_ds_filled['Height_cm'].str.contains("'")])
#final_ds.drop(final_ds[final_ds['Height_cm'].dropna().str.contains("'")].index)
# Out:
#             Name    Birthday         Nationality  \
# 541    Troy Ross  1975-07-17  Georgetown, Guyana
# 918  Paul Pender     unknown             unknown
#
#                               Weight Height           Reach   Stance  \
# 541  Cruiserweight/Light Heavyweight   5'11  1.80 in (5 cm)  unknown
# 918                                   5'10'              72  unknown
#
#     Total Fights Wins Wins by KO Losses    Draws No Contests Sex Height_cm
# 541           28   25         16      3  unknown     unknown   M      5'11
# 918           48   40         20      6        2           0   M     5'10'

# %%
final_ds['Height_cm'][918] = 178

# %%
def othersplits(x):
    try:
        return x.split(')')[0]
    except:
        return x
final_ds['Reach_cm'] = final_ds['Reach_cm'].apply(othersplits)

# %%
final_ds['Reach_cm'] = final_ds['Reach_cm'].str.replace('m', '')

# %%
final_ds_filled['Reach_cm'].str.contains("m").any()
# Out:
# False

# %%
final_ds.head()
# Out:
#                     Name    Birthday                  Place_of_birth  \
# 0  Franchón Crews-Dezurn  1987-06-13  Virginia Beach, Virginia, U.S.
# 1      Savannah Marshall  1991-05-19             Hartlepool, England
# 2       Claressa Shields  1995-03-17                            None
# 4      Chantelle Cameron  1991-05-14            Northampton, England
# 5           Katie Taylor  1986-07-02   Bray, County Wicklow, Ireland
#
#                                               Weight                 Height  \
# 0                                 Super middleweight  5 ft 8 in (173 cm)[1]
# 1                    Middleweight/Super-middleweight  6 ft 0 in (183 cm)[1]
# 2  Light middleweight/Middleweight/Super middlewe...     5 ft 8 in (173 cm)
# 4  Super-featherweight/Lightweight/Light-welterwe...  5 ft 8 in (173 cm)[1]
# 5                      Lightweight/Super-lightweight  5 ft 5 in (165 cm)[1]
#
#                Reach    Stance Total Fights Wins Wins by KO Losses Draws  \
# ...

# %%
final_ds['Country'] = final_ds_filled['Nationality'].str.split(',').str[-1]

# %%
final_ds.to_csv('final_data.csv')

# %%
final_ds.rename(columns={'Nationality': 'Place_of_birth'}, inplace=True)

# %%
final_ds.reset_index(drop=True, inplace=True)

# %%
import pandas as pd
final_ds = pd.read_csv('final_data.csv')

# %%
final_ds
# Out:
#                        Name    Birthday                  Place_of_birth  \
# 0     Franchón Crews-Dezurn  1987-06-13  Virginia Beach, Virginia, U.S.
# 1         Savannah Marshall  1991-05-19             Hartlepool, England
# 2          Claressa Shields  1995-03-17                             NaN
# 3         Chantelle Cameron  1991-05-14            Northampton, England
# 4              Katie Taylor  1986-07-02   Bray, County Wicklow, Ireland
# ...                     ...         ...                             ...
# 1944           Pedro Flores  1951-01-14    Guadalajara, Jalisco, Mexico
# 1945            Lupe Madera         NaN                             NaN
# 1946       Francisco Quiróz         NaN                             NaN
# 1947         Carlos Murillo  1970-12-10                          Panama
# 1948        Keiji Yamaguchi         NaN                             NaN
#
#                                                  Weight  \
# ...

# %%
final_ds.drop(columns=['Unnamed: 0'], inplace=True)

# %%
final_ds['Country'] = final_ds['Country'].str.strip()

# %%
final_ds_filled = final_ds.fillna('unknown')

# %%
ll = final_ds['Country'].value_counts()

# %%
for key,elt in ll.items():
    print(key, elt)
# Out:
# unknown 405
# U.S. 291
# Mexico 160
# England 84
# Japan 82
# Argentina 52
# Puerto Rico 44
# South Africa 43
# Thailand 41
# South Korea 38
# Philippines 37
# Venezuela 32
# Soviet Union 28
# Colombia 27
# Italy 25
# Panama 25
# USA 22
# Dominican Republic 21
# Australia 21
# France 21
# Cuba 19
# Nicaragua 13
# Spain 13
# New York 11
# Northern Ireland 10
# Wales 10
# Ghana 10
# Scotland 10
# United States 10
# Jamaica 10
# Canada 9
# Russia 8
# Guyana 8
# Sweden 8
# Germany 7
# Pennsylvania 6
# Soviet Union (now Russia) 6
# US 6
# West Germany 6
# Indonesia 6
# Brazil 6
# Ireland 6
# Denmark 5
# U.S.[2] 5
# East Germany 5
# China 4
# Namibia 4
# Uganda 4
# Georgia 4
# California 4
# SFR Yugoslavia 4
# Ohio 4
# Haiti 4
# USCAR(nowadays Japan) 4
# Poland 4
# Peru 3
# USSR 3
# Cameroon 3
# Japan[1] 3
# New Jersey 3
# Tunisia 3
# Belgium 3
# Hungary 3
# Nigeria 3
# U.S 2
# London 2
# Soviet Union(now Ukraine) 2
# Italy[1] 2
# [1] Japan 2
# Buenos Aires 2
# U.S.[1] 2
# ...

# %%
final_ds.loc[final_ds_filled['Country'].str.contains('Soviet Union'),'Country']

# %%
'a'

# %%
for key, elt in rus.items():
    final_ds['Country'][key] = 'Russia'

# %%
uss = final_ds.loc[final_ds_filled['Country'].str.contains('^U.S.|^United States|^US|^U.S.[2]|^California|^Ohio|^New Jersey|^American|^U.S|^U.S.[1]|Texas|^U.S. Virgin Islands|^U.S.[3]|^United States|^Territory of Hawaii|^Minnesota|^Tennessee|^Oklahoma|^United States[2]|^Rhode Island|^Louisiana|^New York City|^U.S.|^Connecticut|^Washington|^New York'),'Country']

# %%
for key, elt in uss.items():
    final_ds['Country'][key] = 'USA'

# %%
# Assuming 'final_ds_filled' is a DataFrame containing your data
uss = final_ds.loc[final_ds_filled['Country'].str.contains('^U.S\.|^United States|^US|^U\.S\.[2]|^California|^Ohio|^New Jersey|^American|^U\.S|^U\.S\.[1]|^Texas|^U\.S\. Virgin Islands|^U\.S\.[3]|^United States|^Territory of Hawaii|^Minnesota|^Tennessee|^Oklahoma|^United States[2]|^Rhode Island|^Louisiana|^New York City|^U\.S\.|^Connecticut|^Washington|^New York'),'Country']

# Assuming 'final_ds' is the DataFrame where you want to update the 'Country' column
for key, elt in uss.items():
    final_ds.at[key, 'Country'] = 'USA'
